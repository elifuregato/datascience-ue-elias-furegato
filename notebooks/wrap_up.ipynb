# %% [markdown]
# # Wrap-Up zur Datenanalyse in pandas

# %% [markdown]
# * Daten laden
# * Daten explorieren
# * Daten visualissieren
# * Unsupervised learing mir sklearn

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pandas import read_csv
from matplotlib import pyplot as plt
from os.path import isdir
from os import makedirs

# %%
# Damit wir Daten laden können, müssen wir diese zuerst in Colab hochladen!!!

# %%
df = read_csv("../data/titanic.csv")

# %% [markdown]
# # Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
# Ausgabe der Datensätze von oben
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
# Ausgabe der Datensätze von unten
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df["Pclass"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Pclass"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Pclass'>

# %%
df["Age"].value_counts().sort_index().plot(kind="barh", figsize=(6,20))
plt.title("Distribution of Age")
plt.xlabel("Number if persons")
plt.ylabel("Age of Group")
plt.savefig("../age_plot.png")

# %%
df["Age"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Age'>

# %%
from seaborn import pairplot

# %%
pairplot(df[['Age', "Pclass", "Fare", "Survived"]], hue="Survived")
